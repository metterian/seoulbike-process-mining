# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter


from collections import Counter
import csv
with open('google_reviews.csv', 'r',encoding ='utf-8-sig') as f:
    reader = csv.DictReader(f)
    rating = [] 
    author = []
    content = []
    time = []
    for row in reader:
     
        content.append(row['content'])
        rating.append(row['rating'])

# %%
df = pd.read_csv('google_reviews.csv')
df.head()
# Out:
#    rating        time software_type           author  country_id language  \
# 0       1  2019-08-07   google_play              박경서         147       ko
# 1       5  2019-08-06   google_play  Yoon Jeong Shim         147       ko
# 2       1  2019-08-04   google_play              이영광         147       ko
# 3       4  2019-08-04   google_play              박대정         147       ko
# 4       1  2019-08-03   google_play            정해욱해욱         147       ko
#
#                                              content  \
# 0  따릉이 잘쓰고 있어요 젛은 프로그램이라고 생각됩니다 상담원분들도 친절하시고 그러나 ...
# 1                                            따릉아 사랑해
# 2  어플 켤때마다 로그인 다시 해야되고 삼성패스 해놔도 이 어플만 자꾸 풀림. 결제도 ...
# 3                                                좋아요
# 4  진짜 왠만하면 안남기는데 결제시스템 개짜증난다 결제는 왜 안돼는거지? 카카오도안돼 ...
#
#                                                  url Sentiment(From Appbot)
# 0  https://appbot.co/apps/2127682/reviews/1280444024                neutral
# ...

# %%
del df['software_type']
del df['language']
df.head()
# Out:
#    rating        time           author  \
# 0       1  2019-08-07              박경서
# 1       5  2019-08-06  Yoon Jeong Shim
# 2       1  2019-08-04              이영광
# 3       4  2019-08-04              박대정
# 4       1  2019-08-03            정해욱해욱
#
#                                              content  \
# 0  따릉이 잘쓰고 있어요 젛은 프로그램이라고 생각됩니다 상담원분들도 친절하시고 그러나 ...
# 1                                            따릉아 사랑해
# 2  어플 켤때마다 로그인 다시 해야되고 삼성패스 해놔도 이 어플만 자꾸 풀림. 결제도 ...
# 3                                                좋아요
# 4  진짜 왠만하면 안남기는데 결제시스템 개짜증난다 결제는 왜 안돼는거지? 카카오도안돼 ...
#
#                                                  url Sentiment(From Appbot)
# 0  https://appbot.co/apps/2127682/reviews/1280444024                neutral
# 1  https://appbot.co/apps/2127682/reviews/1280444025               positive
# 2  https://appbot.co/apps/2127682/reviews/1278241596                neutral
# 3  https://appbot.co/apps/2127682/reviews/1278241600               positive
# ...

# %%
from datetime import date, time, datetime
from dateutil.parser import parse
from pandas import Series, DataFrame
df2 = df[['time','rating']]
years = []
mon = []
a = parse('2015-05-24').year
for year in df['time']:
    y = parse(year).year
    years.append(y)
    m = parse(year).month
    mon.append(m)
    
df2['year'] = years
df2['month'] = mon
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
d2015 = df2.loc[df2['year']==2015, :]
d2016 = df2.loc[df2['year']==2016, :]
d2017 = df2.loc[df2['year']==2017, :]
d2018 = df2.loc[df2['year']==2018, :]
d2019 = df2.loc[df2['year']==2019, :]
#monthly_avg = pd.DataFrame(columns=[ "2015", "2016","2017","2018","2019"],index = ["1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월"])
monthly_avg = pd.DataFrame(columns=[ "rating"]
                           ,index = ["1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월"])

monthly_avg
# Out:
#     rating
# 1월     NaN
# 2월     NaN
# 3월     NaN
# 4월     NaN
# 5월     NaN
# 6월     NaN
# 7월     NaN
# 8월     NaN
# 9월     NaN
# 10월    NaN
# 11월    NaN
# 12월    NaN

# %%
k =2015
l=df2.loc[df2['year']==k ,:]
l.loc[l['month']==12,:].mean()
monthly_avg["2015"]=1

# %%
avgs= []


for year in range(2015,2020):
    k=df2.loc[df2['year']==year, :]
    for month in range(1,13):
        i =k.loc[ k['month']==month,:].mean()
        avgs.append(i[0])
        
print(avgs)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, 2.3333333333333335, 1.826086956521739, 2.111111111111111, 4.25, nan, 3.6666666666666665, 2.0, 1.8333333333333333, 2.7777777777777777, 2.111111111111111, 1.736842105263158, 2.6956521739130435, 1.7419354838709677, 2.8275862068965516, 2.125, 2.272727272727273, 2.5, 1.0, 1.5263157894736843, 1.9545454545454546, 2.0, 1.7045454545454546, 2.1363636363636362, 2.8333333333333335, 1.6071428571428572, 1.9411764705882353, 2.6666666666666665, 2.75, 2.3333333333333335, 2.0, 3.375, 1.475, 1.2542372881355932, 1.219277108433735, 1.2244897959183674, 1.4375, 1.8863636363636365, 1.3478260869565217, 1.6, 1.65, 1.3888888888888888, 1.605263157894737, 1.4523809523809523, 1.8035714285714286, 1.736842105263158, 1.575, 1.3066666666666666, 1.6923076923076923, nan, nan, nan, nan]
